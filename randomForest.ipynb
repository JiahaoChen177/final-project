# %%
import pandas as pd
import numpy as np
import random
import math


class Tree(object):
    def __init__(self):
        self.split_feature = None
        self.split_value = None
        self.leaf_value = None
        self.tree_left = None
        self.tree_right = None

    def calc_predict_value(self, dataset):
        if self.leaf_value is not None:
            return self.leaf_value
        elif dataset[self.split_feature] <= self.split_value:
            return self.tree_left.calc_predict_value(dataset)
        else:
            return self.tree_right.calc_predict_value(dataset)

    def describe_tree(self):

        if not self.tree_left and not self.tree_right:
            leaf_info = "{leaf_value:" + str(self.leaf_value) + "}"
            return leaf_info
        left_info = self.tree_left.describe_tree()
        right_info = self.tree_right.describe_tree()
        tree_structure = "{split_feature:" + str(self.split_feature) + \
                         ",split_value:" + str(self.split_value) + \
                         ",left_tree:" + left_info + \
                         ",right_tree:" + right_info + "}"
        return tree_structure


class RandomForestRegression(object):
    def __init__(self, n_estimators=10, max_depth=-1, min_samples_split=2, min_samples_leaf=1,
                 min_split_gain=0.0, colsample_bytree=None, subsample=0.8, random_state=None):

        self.n_estimators = n_estimators
        self.max_depth = max_depth if max_depth != -1 else float('inf')
        self.min_samples_split = min_samples_split
        self.min_samples_leaf = min_samples_leaf
        self.min_split_gain = min_split_gain
        self.colsample_bytree = colsample_bytree
        self.subsample = subsample
        self.random_state = random_state
        self.trees = None
        self.feature_importances_ = dict()

    def fit(self, dataset, targets):

        targets = targets.to_frame(name='label')

        if self.random_state:
            random.seed(self.random_state)
        random_state_stages = random.sample(range(self.n_estimators), self.n_estimators)

        
        if self.colsample_bytree == "sqrt":
            self.colsample_bytree = int(len(dataset.columns) ** 0.5)
        elif self.colsample_bytree == "log2":
            self.colsample_bytree = int(math.log(len(dataset.columns)))
        else:
            self.colsample_bytree = len(dataset.columns)


        self.trees = []
        for random_state in random_state_stages:
            self.trees.append(self._parallel_build_trees(dataset, targets, random_state))
        
    def _parallel_build_trees(self, dataset, targets, random_state):
      
        subcol_index = random.sample(dataset.columns.tolist(), self.colsample_bytree)
        dataset_stage = dataset.sample(n=int(self.subsample * len(dataset)), replace=True, 
                                        random_state=random_state).reset_index(drop=True)
        dataset_stage = dataset_stage.loc[:, subcol_index]
        targets_stage = targets.sample(n=int(self.subsample * len(dataset)), replace=True, 
                                        random_state=random_state).reset_index(drop=True)

        tree = self._build_single_tree(dataset_stage, targets_stage, depth=0)
        print(tree.describe_tree())
        return tree

    def _build_single_tree(self, dataset, targets, depth):

        if len(targets['label'].unique()) <= 1 or dataset.__len__() <= self.min_samples_split:
            tree = Tree()
            tree.leaf_value = self.calc_leaf_value(targets['label'])
            return tree

        if depth < self.max_depth:
            best_split_feature, best_split_value, best_split_gain = self.choose_best_feature(dataset, targets)
            left_dataset, right_dataset, left_targets, right_targets = \
                self.split_dataset(dataset, targets, best_split_feature, best_split_value)

            tree = Tree()
         
            if left_dataset.__len__() <= self.min_samples_leaf or \
                    right_dataset.__len__() <= self.min_samples_leaf or \
                    best_split_gain <= self.min_split_gain:
                tree.leaf_value = self.calc_leaf_value(targets['label'])
                return tree
            else:
 
                self.feature_importances_[best_split_feature] = \
                    self.feature_importances_.get(best_split_feature, 0) + 1

                tree.split_feature = best_split_feature
                tree.split_value = best_split_value
                tree.tree_left = self._build_single_tree(left_dataset, left_targets, depth+1)
                tree.tree_right = self._build_single_tree(right_dataset, right_targets, depth+1)
                return tree

        else:
            tree = Tree()
            tree.leaf_value = self.calc_leaf_value(targets['label'])
            return tree

    def choose_best_feature(self, dataset, targets):

        best_split_gain = float("inf")
        best_split_feature = None
        best_split_value = None

        for feature in dataset.columns:
            if dataset[feature].unique().__len__() <= 100:
                unique_values = sorted(dataset[feature].unique().tolist())

            else:
                unique_values = np.unique([np.percentile(dataset[feature], x)
                                           for x in np.linspace(0, 100, 100)])

            # 对可能的分裂阈值求分裂增益，选取增益最大的阈值
            for split_value in unique_values:
                left_targets = targets[dataset[feature] <= split_value]
                right_targets = targets[dataset[feature] > split_value]
                split_gain = self.calc_r2(left_targets['label'], right_targets['label'])

                if split_gain < best_split_gain:
                    best_split_feature = feature
                    best_split_value = split_value
                    best_split_gain = split_gain
        return best_split_feature, best_split_value, best_split_gain

    @staticmethod
    def calc_leaf_value(targets):
    
        return targets.mean()

    @staticmethod
    def calc_r2(left_targets, right_targets):

        r2 = 0
        for targets in [left_targets, right_targets]:
            mean = targets.mean()
            for dt in targets:
                r2 += (dt - mean) ** 2
        return r2

    @staticmethod
    def split_dataset(dataset, targets, split_feature, split_value):

        left_dataset = dataset[dataset[split_feature] <= split_value]
        left_targets = targets[dataset[split_feature] <= split_value]
        right_dataset = dataset[dataset[split_feature] > split_value]
        right_targets = targets[dataset[split_feature] > split_value]
        return left_dataset, right_dataset, left_targets, right_targets

    def predict(self, dataset):
    
        res = []
        for _, row in dataset.iterrows():
            pred_list = []
            
            for tree in self.trees:
                pred_list.append(tree.calc_predict_value(row))
            res.append(sum(pred_list) * 1.0 / len(pred_list))
        return np.array(res)

# %%
df = pd.read_csv("NTN-data.csv").fillna(-1)
df = df.rename(columns={'pH': 'label'})
clf = RandomForestRegression(n_estimators=5,
                             max_depth=5,
                             min_samples_split=50,
                             min_samples_leaf=10,
                             min_split_gain=0.0,
                             colsample_bytree="sqrt",
                             subsample=0.8,
                             random_state=66)
train_count = int(0.7 * len(df))

feature_list = ['Ca', 'Na', 'NH4', 'SO4', 'Cl', 'K', 'NO3']
clf.fit(df.loc[:train_count, feature_list], df.loc[:train_count, 'label'])

print(np.power((df.loc[:train_count, 'label'] - clf.predict(df.loc[:train_count, feature_list])), 2).sum()/ len(df.loc[:train_count, 'label']))
print(np.power((df.loc[train_count:, 'label'] - clf.predict(df.loc[train_count:, feature_list])), 2).sum()/ len(df.loc[train_count:, 'label']))

from sklearn import metrics
print(metrics.mean_squared_error(df.loc[:train_count, 'label'], clf.predict(df.loc[:train_count, feature_list])))
print(metrics.mean_squared_error(df.loc[train_count:, 'label'], clf.predict(df.loc[train_count:, feature_list])))
# Out:
# {split_feature:NO3,split_value:1.070989898989899,left_tree:{leaf_value:4.9151707317073186},right_tree:{split_feature:NO3,split_value:1.962,left_tree:{split_feature:NH4,split_value:0.44799999999999995,left_tree:{split_feature:NO3,split_value:1.143,left_tree:{leaf_value:4.670857142857143},right_tree:{split_feature:NO3,split_value:1.453,left_tree:{leaf_value:4.477634615384615},right_tree:{leaf_value:4.315800000000001}}},right_tree:{leaf_value:4.786057142857143}},right_tree:{leaf_value:4.19796153846154}}}
# {split_feature:NO3,split_value:1.0737474747474751,left_tree:{split_feature:NO3,split_value:0.6553636363636365,left_tree:{split_feature:Cl,split_value:0.11800000000000001,left_tree:{split_feature:NO3,split_value:0.599,left_tree:{leaf_value:5.077863636363636},right_tree:{leaf_value:5.377866666666667}},right_tree:{split_feature:NO3,split_value:0.43700000000000006,left_tree:{leaf_value:5.1106799999999994},right_tree:{leaf_value:4.860692307692307}}},right_tree:{leaf_value:4.821674242424244}},right_tree:{split_feature:NO3,split_value:1.9123030303030302,left_tree:{leaf_value:4.576620689655174},right_tree:{leaf_value:4.252399999999999}}}
# {split_feature:Ca,split_value:0.13164646464646468,left_tree:{leaf_value:4.846729483282673},right_tree:{leaf_value:4.6036875}}
# {split_feature:SO4,split_value:1.217878787878788,left_tree:{split_feature:SO4,split_value:0.555,left_tree:{leaf_value:5.204207920792078},right_tree:{split_feature:NO3,split_value:1.1179999999999999,left_tree:{split_feature:SO4,split_value:0.703,left_tree:{leaf_value:5.001555555555556},right_tree:{split_feature:SO4,split_value:1.097,left_tree:{leaf_value:4.824448979591836},right_tree:{leaf_value:4.608250000000001}}},right_tree:{leaf_value:5.1244642857142875}}},right_tree:{split_feature:SO4,split_value:2.264222222222222,left_tree:{split_feature:SO4,split_value:1.456,left_tree:{leaf_value:4.624545454545455},right_tree:{split_feature:NO3,split_value:1.36,left_tree:{leaf_value:4.490795454545454},right_tree:{leaf_value:4.39875}}},right_tree:{split_feature:SO4,split_value:3.404,left_tree:{split_feature:NO3,split_value:1.9269999999999998,left_tree:{leaf_value:4.362128205128205},right_tree:{leaf_value:4.301692307692307}},right_tree:{leaf_value:4.099772727272726}}}}
# {split_feature:SO4,split_value:0.974,left_tree:{split_feature:SO4,split_value:0.604,left_tree:{leaf_value:5.1586046511627925},right_tree:{split_feature:Na,split_value:0.08199999999999999,left_tree:{leaf_value:4.890750000000001},right_tree:{leaf_value:5.0390500000000005}}},right_tree:{split_feature:SO4,split_value:1.8399999999999999,left_tree:{split_feature:SO4,split_value:1.214,left_tree:{split_feature:Na,split_value:0.11599999999999999,left_tree:{leaf_value:4.703487804878048},right_tree:{leaf_value:4.939909090909091}},right_tree:{leaf_value:4.564905405405409}},right_tree:{split_feature:SO4,split_value:3.0410000000000004,left_tree:{split_feature:SO4,split_value:2.457,left_tree:{leaf_value:4.418611111111112},right_tree:{leaf_value:4.284624999999999}},right_tree:{leaf_value:4.119090909090908}}}}
# 0.059287962724949655
# 0.12114470460405202
# 0.059287962724949655
# 0.12114470460405202

# %%
clf.feature_importances_
# Out:
# {'NO3': 12, 'NH4': 1, 'Cl': 1, 'Ca': 1, 'SO4': 13, 'Na': 2}

# %%
len(df)
# Out:
# 702

# %%
def get_nfolds_datasets(dataset, n_folds, split=0.9):
    all_datasets_splited_train = []
    all_datasets_splited_test = []
    size_one_fold = len(dataset) / n_folds
    for i in range(n_folds):
        left = int(i * len(dataset) / n_folds)
        right = int((i + 1) * len(dataset) / n_folds)
        all_datasets_splited_test.append(dataset.iloc[left:right])
        all_datasets_splited_train.append(pd.concat([dataset.iloc[:left], dataset.iloc[right:]], ignore_index=True))
    return all_datasets_splited_train, all_datasets_splited_test

# %%
all_datasets_splited_train, all_datasets_splited_test = get_nfolds_datasets(df, 10)

# %%
all_datasets_splited_test
# Out:
# [   siteID  month    yr  Criteria1  Criteria2  Criteria3     Ca     Mg      K  \
#  0    VA24      1  1999         20         20        100  0.041  0.072  0.027
#  1    VA24      2  1999        100        100        100  0.164  0.031  0.041
#  2    VA24      3  1999        100        100        100  0.165  0.026  0.022
#  3    VA24      4  1999         67        100         71  0.070  0.038  0.022
#  4    VA24      5  1999         80        100         99  0.077  0.024  0.019
#  ..    ...    ...   ...        ...        ...        ...    ...    ...    ...
#  65   VA24      8  2004        100        100        100  0.042  0.008  0.007
#  66   VA24      9  2004        100        100        100  0.040  0.031  0.016
#  67   VA24     10  2004        100        100        100  0.045  0.009  0.010
#  68   VA24     11  2004        100        100        100  0.031  0.010  0.007
#  69   VA24     12  2004        100        100        100  0.035  0.018  0.015
#
#         Na  ...    SO4  Br  label  conduc    svol     ppt  fullChemLab  \
#  0   0.600  ...  0.790  -9  4.800  12.300  1023.7   1.448            1
#  1   0.180  ...  2.734  -9  4.262  32.451  2252.1   3.251            4
#  2   0.127  ...  1.657  -9  4.487  18.689  5954.5   8.052            4
#  3   0.268  ...  0.810  -9  4.880  10.100  1399.4   2.692            1
#  4   0.120  ...  1.434  -9  4.473  18.953  6375.8  10.135            3
#  ..    ...  ...    ...  ..    ...     ...     ...     ...          ...
#  65  0.055  ...  1.207  -9  4.546  14.702  7505.2  11.055            4
#  66  0.258  ...  0.752  -9  4.830   9.636  7896.9  11.810            4
#  67  0.056  ...  2.034  -9  4.361  23.272  4074.0   6.024            4
#  68  0.088  ...  0.982  -9  4.631  13.303  8439.5  13.030            4
#  69  0.150  ...  1.299  -9  4.516  16.820  4583.0   6.985            3
#
#      daysSample        startDate         lastDate
#  0           35   1999/1/26 0:00    1999/2/2 0:00
#  1           28    1999/2/2 0:00    1999/3/2 0:00
#  2           28    1999/3/2 0:00   1999/3/30 0:00
#  3           21   1999/3/30 0:00   1999/4/20 0:00
#  4           35   1999/4/27 0:00    1999/6/1 0:00
#  ..         ...              ...              ...
#  65          28    2004/8/3 0:00   2004/8/31 0:00
#  66          28   2004/8/31 0:00   2004/9/28 0:00
#  67          35   2004/9/28 0:00   2004/11/2 0:00
#  68          28   2004/11/2 0:00  2004/11/30 0:00
#  69          28  2004/11/30 0:00  2004/12/28 0:00
#
#  [70 rows x 23 columns],
#      siteID  month    yr  Criteria1  Criteria2  Criteria3     Ca     Mg      K  \
#  70    VA24      1  2005        100        100        100  0.043  0.019  0.012
#  71    VA24      2  2005        100        100        100  0.057  0.015  0.012
#  72    VA24      3  2005         75        100         92  0.092  0.016  0.017
#  73    VA24      4  2005         60        100         77  0.109  0.017  0.020
#  74    VA24      5  2005         50        100         88  0.130  0.022  0.030
#  ..     ...    ...   ...        ...        ...        ...    ...    ...    ...
#  135   VA24      7  2010        100        100        100  0.045  0.007  0.007
#  136   VA24      8  2010        100        100        100  0.070  0.009  0.009
#  137   VA24      9  2010        100        100        100  0.085  0.020  0.018
#  138   VA24     10  2010        100        100        100  0.049  0.008  0.013
#  139   VA24     11  2010         75        100         83  0.036  0.019  0.013
#
#          Na  ...    SO4  Br  label  conduc     svol     ppt  fullChemLab  \
#  70   0.190  ...  0.381  -9  4.933   8.340   4969.3   8.230            4
#  71   0.071  ...  1.501  -9  4.432  20.891   2796.1   4.648            4
#  72   0.093  ...  1.251  -9  4.482  19.006   5045.1   8.458            3
#  73   0.078  ...  1.581  -9  4.462  18.583   2300.1   4.674            3
#  74   0.067  ...  2.793  -9  4.338  27.411   4182.6   7.163            2
#  ..     ...  ...    ...  ..    ...     ...      ...     ...          ...
#  135  0.024  ...  0.817  -9  4.711  10.841   4337.5   6.477            4
#  136  0.030  ...  1.109  -9  4.643  13.439   8640.8  14.326            4
#  137  0.106  ...  1.225  -9  4.700  13.084   3412.4   5.232            2
#  138  0.053  ...  0.426  -9  5.111   5.419  12447.4  18.720            4
#  139  0.139  ...  0.586  -9  4.969   7.900   2615.2   4.877            3
#
#       daysSample        startDate         lastDate
#  70           35  2004/12/28 0:00    2005/2/1 0:00
#  71           28    2005/2/1 0:00    2005/3/1 0:00
#  72           28    2005/3/1 0:00   2005/3/29 0:00
#  73           35   2005/3/29 0:00    2005/5/3 0:00
#  74           28    2005/5/3 0:00   2005/5/31 0:00
#  ..          ...              ...              ...
#  135          35   2010/6/29 0:00    2010/8/3 0:00
#  136          28    2010/8/3 0:00   2010/8/31 0:00
#  137          28   2010/8/31 0:00   2010/9/28 0:00
#  138          35   2010/9/28 0:00   2010/11/2 0:00
#  139          28   2010/11/2 0:00  2010/11/30 0:00
#
#  [70 rows x 23 columns],
#      siteID  month    yr  Criteria1  Criteria2  Criteria3     Ca     Mg      K  \
#  140   VA24     12  2010        100        100        100  0.027  0.008  0.009
#  141   VA24      1  2011        100        100        100  0.079  0.008  0.011
#  142   VA24      2  2011        100        100        100  0.157  0.032  0.035
#  143   VA24      3  2011         50        100         64  0.036  0.032  0.016
#  144   VA24      4  2011         60        100         47  0.166  0.033  0.054
#  ..     ...    ...   ...        ...        ...        ...    ...    ...    ...
#  205   VA24      5  2016        100        100        100  0.046  0.014  0.012
#  206   VA24      6  2016        100        100        100  0.078  0.011  0.024
#  207   VA24      7  2016        100        100        100  0.044  0.006  0.008
#  208   VA24      8  2016        100        100        100  0.063  0.018  0.017
#  209   VA24      9  2016        100        100        100  0.009  0.006  0.004
#
#          Na  ...    SO4  Br  label  conduc    svol     ppt  fullChemLab  \
#  140  0.054  ...  0.355  -9  4.865   8.034  3129.8   5.537            4
#  141  0.045  ...  0.701  -9  4.823   9.501  2546.8   4.191            4
#  142  0.202  ...  0.914  -9  4.964  10.015  2805.3   4.521            3
#  143  0.268  ...  0.425  -9  5.205   6.226  3720.6   8.560            2
#  144  0.155  ...  1.136  -9  4.871  11.129  2084.2   7.087            3
#  ..     ...  ...    ...  ..    ...     ...     ...     ...          ...
#  205  0.076  ...  0.366  -9  5.109   6.012  8905.6  13.513            4
#  206  0.030  ...  0.438  -9  4.977   7.269  4580.9   6.985            3
#  207  0.013  ...  0.463  -9  4.836   8.485  7689.0  15.392            4
#  208  0.082  ...  0.760  -9  4.789  10.905  3377.1   4.928            2
#  209  0.054  ...  0.105  -9  5.340   2.986  8599.5  12.802            4
#
#       daysSample        startDate         lastDate
#  140          28  2010/11/30 0:00  2010/12/28 0:00
#  141          35  2010/12/28 0:00    2011/2/1 0:00
#  142          28    2011/2/1 0:00    2011/3/1 0:00
#  143          28    2011/3/1 0:00   2011/3/29 0:00
#  144          35   2011/3/29 0:00    2011/5/3 0:00
#  ..          ...              ...              ...
#  205          28    2016/5/3 0:00   2016/5/31 0:00
#  206          28   2016/5/31 0:00   2016/6/28 0:00
#  207          35   2016/6/28 0:00    2016/8/2 0:00
#  208          28    2016/8/2 0:00   2016/8/30 0:00
#  209          35   2016/8/30 0:00   2016/10/4 0:00
#
#  [70 rows x 23 columns],
#      siteID  month    yr  Criteria1  Criteria2  Criteria3     Ca     Mg      K  \
#  210   VA24     10  2016        100        100        100  0.012  0.025  0.010
#  211   VA24     11  2016        100        100        100  0.126  0.021  0.012
#  212   VA24     12  2016        100        100        100  0.027  0.025  0.015
#  213   VA24      1  2017        100        100        100  0.046  0.008  0.007
#  214   VA24      2  2017        100        100        100  0.066  0.031  0.021
#  ..     ...    ...   ...        ...        ...        ...    ...    ...    ...
#  275   PA00      8  2000        100        100        100  0.116  0.014  0.015
#  276   PA00      9  2000        100        100        100  0.074  0.014  0.014
#  277   PA00     10  2000         75        100         69  0.158  0.050  0.040
#  278   PA00     11  2000         75        100         41  0.074  0.010  0.013
#  279   PA00     12  2000        100        100        100  0.040  0.006  0.003
#
#          Na  ...    SO4  Br  label  conduc     svol     ppt  fullChemLab  \
#  210  0.202  ...  0.134  -9  5.360   3.800   7046.0  10.693            1
#  211  0.044  ...  0.413  -9  5.095   6.571    892.9   1.422            2
#  212  0.204  ...  0.330  -9  4.982   6.763   6917.8  10.167            4
#  213  0.057  ...  0.215  -9  5.079   4.767   5707.5   8.841            4
#  214  0.225  ...  0.388  -9  5.186   6.501   1248.1   1.877            3
#  ..     ...  ...    ...  ..    ...     ...      ...     ...          ...
#  275  0.034  ...  3.206  -9  4.227  34.699   2729.7   4.343            4
#  276  0.076  ...  1.663  -9  4.429  20.536  16086.8  23.924            4
#  277  0.295  ...  5.982  -9  3.975  67.393    741.9   1.651            2
#  278  0.061  ...  2.382  -9  4.360  27.100   1597.7   6.185            1
#  279  0.050  ...  0.947  -9  4.621  13.072   6019.1   9.198            3
#
#       daysSample        startDate         lastDate
#  210          28   2016/10/4 0:00   2016/11/1 0:00
#  211          28   2016/11/1 0:00  2016/11/29 0:00
#  212          35  2016/11/29 0:00    2017/1/3 0:00
#  213          28    2017/1/3 0:00   2017/1/31 0:00
#  214          28   2017/1/31 0:00   2017/2/28 0:00
#  ..          ...              ...              ...
#  275          28    2000/8/1 0:00   2000/8/29 0:00
#  276          35   2000/8/29 0:00   2000/10/3 0:00
#  277          28   2000/10/3 0:00  2000/10/31 0:00
#  278          28  2000/10/31 0:00  2000/11/28 0:00
#  279          35  2000/11/28 0:00    2001/1/2 0:00
#
#  [70 rows x 23 columns],
#      siteID  month    yr  Criteria1  Criteria2  Criteria3     Ca     Mg      K  \
#  280   PA00      1  2001        100        100        100  0.029  0.003  0.006
#  281   PA00      2  2001         75        100         56  0.164  0.021  0.010
#  282   PA00      3  2001        100        100        100  0.059  0.013  0.005
#  283   PA00      4  2001         75        100         61  0.252  0.032  0.018
#  284   PA00      5  2001         75        100         94  0.130  0.014  0.014
#  ..     ...    ...   ...        ...        ...        ...    ...    ...    ...
#  346   PA00      7  2006        100        100        100  0.097  0.014  0.011
#  347   PA00      8  2006        100        100        100  0.182  0.042  0.026
#  348   PA00      9  2006        100        100        100  0.038  0.005  0.006
#  349   PA00     10  2006        100        100        100  0.044  0.006  0.012
#  350   PA00     11  2006        100        100        100  0.056  0.017  0.012
#
#          Na  ...    SO4  Br  label  conduc    svol     ppt  fullChemLab  \
#  280  0.012  ...  1.322  -9  4.421  20.357  3626.1   5.690            3
#  281  0.033  ...  2.265  -9  4.257  32.349   863.7   2.388            2
#  282  0.053  ...  1.698  -9  4.439  21.709  7674.2  11.633            5
#  283  0.036  ...  3.009  -9  4.330  30.567  1855.5   5.004            2
#  284  0.027  ...  2.640  -9  4.518  23.417  4096.2   6.896            2
#  ..     ...  ...    ...  ..    ...     ...     ...     ...          ...
#  346  0.036  ...  2.595  -9  4.309  25.945  8271.0  12.852            5
#  347  0.228  ...  4.385  -9  4.157  40.536  1195.0   1.829            3
#  348  0.016  ...  1.042  -9  4.727  10.340  5096.2   7.603            5
#  349  0.011  ...  1.111  -9  4.633  12.506  7619.9  11.224            4
#  350  0.109  ...  1.180  -9  4.618  14.021  6998.6  10.549            4
#
#       daysSample        startDate         lastDate
#  280          28    2001/1/2 0:00   2001/1/30 0:00
#  281          28   2001/1/30 0:00   2001/2/27 0:00
#  282          35   2001/2/27 0:00    2001/4/3 0:00
#  283          28    2001/4/3 0:00    2001/5/1 0:00
#  284          28    2001/5/1 0:00   2001/5/29 0:00
#  ..          ...              ...              ...
#  346          35   2006/6/27 0:00    2006/8/1 0:00
#  347          28    2006/8/1 0:00   2006/8/29 0:00
#  348          35   2006/8/29 0:00   2006/10/3 0:00
#  349          28   2006/10/3 0:00  2006/10/31 0:00
#  350          28  2006/10/31 0:00  2006/11/28 0:00
#
#  [71 rows x 23 columns],
#      siteID  month    yr  Criteria1  Criteria2  Criteria3     Ca     Mg      K  \
#  351   PA00     12  2006        100        100        100  0.042  0.008  0.008
#  352   PA00      1  2007        100        100        100  0.077  0.008  0.009
#  353   PA00      2  2007         75        100         96  0.145  0.013  0.010
#  354   PA00      3  2007         80        100         97  0.145  0.017  0.011
#  355   PA00      4  2007         50        100         82  0.066  0.011  0.010
#  ..     ...    ...   ...        ...        ...        ...    ...    ...    ...
#  416   PA00      5  2012        100        100        100  0.116  0.032  0.027
#  417   PA00      6  2012         60        100         92  0.047  0.011  0.016
#  418   PA00      7  2012         75        100         96  0.172  0.025  0.016
#  419   PA00      8  2012        100        100        100  0.128  0.019  0.020
#  420   PA00      9  2012        100        100        100  0.073  0.015  0.012
#
#          Na  ...    SO4  Br  label  conduc     svol     ppt  fullChemLab  \
#  351  0.057  ...  1.496  -9  4.453  17.586   5649.8   8.632            4
#  352  0.038  ...  1.467  -9  4.456  17.857   2173.7   3.607            3
#  353  0.099  ...  1.036  -9  4.660  13.063   3902.0   5.994            3
#  354  0.076  ...  1.918  -9  4.426  21.243   6335.7  11.151            4
#  355  0.037  ...  1.851  -9  4.490  17.900   5380.7   9.703            1
#  ..     ...  ...    ...  ..    ...     ...      ...     ...          ...
#  416  0.164  ...  1.148  -9  5.051  10.581   8489.9  12.802            4
#  417  0.036  ...  0.599  -9  5.300   6.043   5867.4   9.398            3
#  418  0.028  ...  0.762  -9  4.826  14.066   7573.6  12.192            3
#  419  0.045  ...  0.861  -9  4.964   9.489   4902.5   7.899            4
#  420  0.051  ...  0.742  -9  4.984   7.759  10365.4  15.799            5
#
#       daysSample        startDate        lastDate
#  351          35  2006/11/28 0:00   2007/1/2 0:00
#  352          28    2007/1/2 0:00  2007/1/30 0:00
#  353          28   2007/1/30 0:00  2007/2/27 0:00
#  354          35   2007/2/27 0:00   2007/4/3 0:00
#  355          28    2007/4/3 0:00   2007/5/1 0:00
#  ..          ...              ...             ...
#  416          28    2012/5/1 0:00  2012/5/29 0:00
#  417          35   2012/5/29 0:00   2012/7/3 0:00
#  418          28    2012/7/3 0:00  2012/7/31 0:00
#  419          28   2012/7/31 0:00  2012/8/28 0:00
#  420          35   2012/8/28 0:00  2012/10/2 0:00
#
#  [70 rows x 23 columns],
#      siteID  month    yr  Criteria1  Criteria2  Criteria3     Ca     Mg      K  \
#  421   PA00     10  2012         75        100         22  0.119  0.026  0.015
#  422   PA00     11  2012         75        100         91  0.109  0.016  0.015
#  423   PA00     12  2012         56        100         18  0.101  0.012  0.011
#  424   PA00      1  2013        100        100        100  0.078  0.012  0.006
#  425   PA00      2  2013        100        100        100  0.074  0.011  0.007
#  ..     ...    ...   ...        ...        ...        ...    ...    ...    ...
#  486   PA00      3  2018         57        100         75  0.081  0.012  0.013
#  487   PA00      4  2018         50        100         16  0.276  0.040  0.032
#  488   PA00      5  2018         75        100         86  0.087  0.019  0.031
#  489   PA00      6  2018        100        100        100  0.082  0.013  0.016
#  490   PA00      7  2018        100        100        100  0.030  0.006  0.007
#
#          Na  ...    SO4  Br  label  conduc     svol     ppt  fullChemLab  \
#  421  0.121  ...  0.868  -9  5.047   9.045   2240.4  17.297            3
#  422  0.045  ...  0.627  -9  4.881   9.542   1595.8   2.565            2
#  423  0.047  ...  0.944  -9  4.744  13.916   1252.8  12.014            3
#  424  0.079  ...  0.699  -9  4.862   9.335   2516.2   4.039            3
#  425  0.054  ...  0.425  -9  5.204   5.491   3845.9   6.579            4
#  ..     ...  ...    ...  ..    ...     ...      ...     ...          ...
#  486  0.033  ...  0.384  -9  4.992   7.900   2919.6   4.293            2
#  487  0.154  ...  0.844  -9  5.703   9.322   1194.7   8.433            2
#  488  0.064  ...  0.555  -9  5.921   7.007   5848.6   8.788            3
#  489  0.047  ...  0.459  -9  5.858   6.423   9674.3  14.554            5
#  490  0.070  ...  0.147  -9  5.389   3.170  14427.4  24.700            3
#
#       daysSample        startDate         lastDate
#  421          28   2012/10/2 0:00  2012/10/30 0:00
#  422          28  2012/10/30 0:00  2012/11/27 0:00
#  423          36  2012/11/27 0:00    2013/1/2 0:00
#  424          27    2013/1/2 0:00   2013/1/29 0:00
#  425          28   2013/1/29 0:00   2013/2/26 0:00
#  ..          ...              ...              ...
#  486          35   2018/2/27 0:00    2018/4/3 0:00
#  487          28    2018/4/3 0:00    2018/5/1 0:00
#  488          28    2018/5/1 0:00   2018/5/29 0:00
#  489          35   2018/5/29 0:00    2018/7/3 0:00
#  490          28    2018/7/3 0:00   2018/7/31 0:00
#
#  [70 rows x 23 columns],
#      siteID  month    yr  Criteria1  Criteria2  Criteria3     Ca     Mg      K  \
#  491   PA00      8  2018        100        100        100  0.065  0.012  0.015
#  492   PA00      9  2018        100        100        100  0.034  0.010  0.009
#  493   PA00     10  2018        100        100        100  0.056  0.010  0.009
#  494   PA00     11  2018        100        100        100  0.023  0.009  0.006
#  495   PA00     12  2018        100        100        100  0.017  0.004  0.004
#  ..     ...    ...   ...        ...        ...        ...    ...    ...    ...
#  556   MD99     12  2007         78        100         91  0.058  0.018  0.013
#  557   MD99      1  2008        100        100        100  0.069  0.016  0.018
#  558   MD99      2  2008        100        100        100  0.120  0.049  0.022
#  559   MD99      3  2008        100        100        100  0.211  0.052  0.034
#  560   MD99      4  2008         52        100         27  0.090  0.024  0.043
#
#          Na  ...    SO4  Br  label  conduc     svol     ppt  fullChemLab  \
#  491  0.063  ...  0.337  -9  5.325   4.746   8603.8  12.837            4
#  492  0.067  ...  0.284  -9  5.374   4.314  23087.5  34.188            5
#  493  0.038  ...  0.260  -9  5.595   3.970   3985.2   6.350            4
#  494  0.065  ...  0.219  -9  5.234   4.521  13216.9  22.049            5
#  495  0.033  ...  0.151  -9  5.177   3.966   9719.1  14.369            3
#  ..     ...  ...    ...  ..    ...     ...      ...     ...          ...
#  556  0.143  ...  1.591  -9  4.368  22.241   5399.9   8.204            4
#  557  0.090  ...  1.160  -9  4.585  14.023   2362.6   3.073            4
#  558  0.390  ...  1.416  -9  4.599  17.071   6375.6   9.220            4
#  559  0.300  ...  1.607  -9  4.678  17.118   4257.7   6.299            5
#  560  0.093  ...  1.072  -9  4.633  12.850   2215.1  12.903            2
#
#       daysSample        startDate         lastDate
#  491          28   2018/7/31 0:00   2018/8/28 0:00
#  492          35   2018/8/28 0:00   2018/10/2 0:00
#  493          28   2018/10/2 0:00  2018/10/30 0:00
#  494          35  2018/10/30 0:00   2018/12/4 0:00
#  495          29   2018/12/4 0:00    2019/1/2 0:00
#  ..          ...              ...              ...
#  556          37  2007/11/27 0:00    2008/1/3 0:00
#  557          27    2008/1/3 0:00   2008/1/30 0:00
#  558          28   2008/1/30 0:00   2008/2/27 0:00
#  559          34   2008/2/27 0:00    2008/4/1 0:00
#  560          29    2008/4/1 0:00   2008/4/30 0:00
#
#  [70 rows x 23 columns],
#      siteID  month    yr  Criteria1  Criteria2  Criteria3     Ca     Mg      K  \
#  561   MD99      5  2008         79        100         26  0.172  0.029  0.056
#  562   MD99      6  2008         75        100         78  0.126  0.019  0.047
#  563   MD99      7  2008         75        100         78  0.072  0.010  0.022
#  564   MD99      8  2008         61        100         95  0.252  0.065  0.031
#  565   MD99      9  2008         29        100         51  0.053  0.046  0.026
#  ..     ...    ...   ...        ...        ...        ...    ...    ...    ...
#  626   MD99     11  2013         80        100         30  0.084  0.034  0.022
#  627   MD99     12  2013        100        100        100  0.027  0.008  0.015
#  628   MD99      1  2014        100        100        100  0.079  0.061  0.769
#  629   MD99      2  2014        100        100        100  0.038  0.009  0.009
#  630   MD99      3  2014         57        100         69  0.021  0.004  0.007
#
#          Na  ...    SO4  Br  label  conduc    svol     ppt  fullChemLab  \
#  561  0.033  ...  1.541  -9  4.953  10.787  4268.4  22.335            3
#  562  0.028  ...  1.427  -9  4.641  13.366  6631.0  12.040            3
#  563  0.010  ...  1.642  -9  4.413  18.250  5784.2  10.566            2
#  564  0.239  ...  2.833  -9  4.253  29.400  2644.3   4.420            3
#  565  0.394  ...  0.861  -9  4.920   9.700  4018.7  10.897            1
#  ..     ...  ...    ...  ..    ...     ...     ...     ...          ...
#  626  0.202  ...  0.814  -9  5.056   9.089  1461.9   7.671            4
#  627  0.063  ...  0.531  -9  4.934   7.314  8300.0  13.564            4
#  628  0.174  ...  0.650  -9  5.121   9.487  3778.6   6.883            3
#  629  0.074  ...  0.645  -9  4.817   9.600  7213.8  12.624            4
#  630  0.067  ...  0.266  -9  5.212   4.384  5717.7  12.903            2
#
#       daysSample        startDate         lastDate
#  561          34   2008/4/30 0:00    2008/6/3 0:00
#  562          28    2008/6/3 0:00    2008/7/1 0:00
#  563          28    2008/7/1 0:00   2008/7/29 0:00
#  564          36   2008/7/29 0:00    2008/9/3 0:00
#  565          28    2008/9/3 0:00   2008/10/1 0:00
#  ..          ...              ...              ...
#  626          35  2013/10/29 0:00   2013/12/3 0:00
#  627          28   2013/12/3 0:00  2013/12/31 0:00
#  628          28  2013/12/31 0:00   2014/1/28 0:00
#  629          28   2014/1/28 0:00   2014/2/25 0:00
#  630          35   2014/2/25 0:00    2014/4/1 0:00
#
#  [70 rows x 23 columns],
#      siteID  month    yr  Criteria1  Criteria2  Criteria3     Ca     Mg      K  \
#  631   MD99      4  2014         80        100         99  0.039  0.017  0.016
#  632   MD99      5  2014         58        100         55  0.155  0.025  0.038
#  633   MD99      6  2014         75        100         61  0.095  0.015  0.018
#  634   MD99      7  2014        100        100        100  0.138  0.021  0.019
#  635   MD99      8  2014        100        100        100  0.047  0.027  0.023
#  ..     ...    ...   ...        ...        ...        ...    ...    ...    ...
#  697   MD99      2  2020         93        100         89  0.077  0.019  0.160
#  698   MD99      3  2020         75        100         53  0.168  0.037  0.045
#  699   MD99      5  2020         90         90        100  0.131  0.059  0.064
#  700   MD99      6  2020         25        100         20  0.080  0.021  0.018
#  701   MD99      7  2020         21         62         62  0.113  0.016  0.059
#
#          Na  ...    SO4  Br  label  conduc      svol     ppt  fullChemLab  \
#  631  0.109  ...  0.590  -9  5.114   6.563  11575.70  17.932            4
#  632  0.053  ...  1.016  -9  5.272   7.961   3636.40  10.074            2
#  633  0.040  ...  0.801  -9  4.938   8.335   4676.99  11.354            3
#  634  0.051  ...  0.551  -9  4.946   7.755   4133.90   8.509            4
#  635  0.201  ...  0.488  -9  4.938   8.149   6245.30   9.550            4
#  ..     ...  ...    ...  ..    ...     ...       ...     ...          ...
#  697  0.107  ...  0.303  -9  5.490   5.768   5421.60   9.196            4
#  698  0.196  ...  0.782  -9  5.657   9.772   2219.80   6.782            3
#  699  0.365  ...  0.442  -9  5.671   7.530   5471.00   8.179            3
#  700  0.111  ...  0.292  -9  5.660   4.300   1410.60  11.031            1
#  701  0.014  ...  0.418  -9  5.360   6.900   6266.20  15.037            1
#
#       daysSample       startDate        lastDate
#  631          30   2014/4/1 0:00   2014/5/1 0:00
#  632          33   2014/5/1 0:00   2014/6/3 0:00
#  633          28   2014/6/3 0:00   2014/7/1 0:00
#  634          28   2014/7/1 0:00  2014/7/29 0:00
#  635          35  2014/7/29 0:00   2014/9/2 0:00
#  ..          ...             ...             ...
#  697          28  2020/1/28 0:00   2020/3/3 0:00
#  698          28   2020/3/3 0:00  2020/3/31 0:00
#  699          31  2020/4/28 0:00  2020/5/26 0:00
#  700          28  2020/5/26 0:00  2020/6/30 0:00
#  701          34  2020/6/30 0:00  2020/7/28 0:00
#
#  [71 rows x 23 columns]]

# %%
print(np.power((all_datasets_splited_test[0].loc[:, 'label'] - clf.predict(all_datasets_splited_test[0].loc[:, feature_list])), 2).sum()/ len(all_datasets_splited_test[0].loc[:, 'label']))
# Out:
# 0.0396883188219255

# %%
df = pd.read_csv("NTN-data.csv").fillna(-1)
df = df.rename(columns={'pH': 'label'})

def cross_validate(df, n_folds=10):
    all_datasets_splited_train, all_datasets_splited_test = get_nfolds_datasets(df, n_folds)
    
    for i in range(n_folds):
        clf = RandomForestRegression(n_estimators=5,
                                     max_depth=5,
                                     min_samples_split=50,
                                     min_samples_leaf=10,
                                     min_split_gain=0.0,
                                     colsample_bytree="sqrt",
                                     subsample=0.8,
                                     random_state=66)
        train_count = int(0.8 * len(df))

        

        feature_list = ['Ca', 'Na', 'NH4', 'SO4', 'Cl', 'K', 'NO3']
        
        clf.fit(all_datasets_splited_train[i].loc[:train_count, feature_list], all_datasets_splited_train[i].loc[:train_count, 'label'])

        print("feature importance:", clf.feature_importances_)

        print(f"fold: {i}, error train:", np.power((all_datasets_splited_train[i].loc[:train_count, 'label'] - clf.predict(all_datasets_splited_train[i].loc[:train_count, feature_list])), 2).sum()/ len(all_datasets_splited_train[i].loc[:train_count, 'label']))
        print(f"fold: {i}, error val:", np.power((all_datasets_splited_train[i].loc[train_count:, 'label'] - clf.predict(all_datasets_splited_train[i].loc[train_count:, feature_list])), 2).sum()/ len(all_datasets_splited_train[i].loc[train_count:, 'label']))
        print(f"fold: {i}, error test:", np.power((all_datasets_splited_test[i].loc[:, 'label'] - clf.predict(all_datasets_splited_test[i].loc[:, feature_list])), 2).sum()/ len(all_datasets_splited_test[i].loc[:, 'label']))

cross_validate(df, 10)
# Out:
# {split_feature:NO3,split_value:1.072,left_tree:{split_feature:NH4,split_value:0.3240707070707073,left_tree:{split_feature:NO3,split_value:0.6210909090909091,left_tree:{split_feature:NH4,split_value:0.25,left_tree:{split_feature:NO3,split_value:0.27,left_tree:{leaf_value:5.285291666666668},right_tree:{leaf_value:5.037880952380953}},right_tree:{leaf_value:5.523636363636364}},right_tree:{split_feature:NO3,split_value:0.755,left_tree:{split_feature:NH4,split_value:0.21100000000000002,left_tree:{leaf_value:4.805137931034483},right_tree:{leaf_value:5.055913043478259}},right_tree:{split_feature:NH4,split_value:0.251,left_tree:{leaf_value:4.646016666666667},right_tree:{leaf_value:4.836967741935484}}}},right_tree:{leaf_value:5.533232558139534}},right_tree:{split_feature:NO3,split_value:1.841,left_tree:{split_feature:NH4,split_value:0.521,left_tree:{split_feature:NO3,split_value:1.5419999999999998,left_tree:{leaf_value:4.603448275862069},right_tree:{leaf_value:4.398176470588235}},right_tree:{leaf_value:4.843538461538461}},right_tree:{leaf_value:4.2443255813953495}}}
# {split_feature:NO3,split_value:1.5217373737373745,left_tree:{split_feature:NO3,split_value:0.67,left_tree:{split_feature:NO3,split_value:0.609,left_tree:{leaf_value:5.067657657657658},right_tree:{leaf_value:5.192130434782608}},right_tree:{split_feature:Cl,split_value:0.05815151515151515,left_tree:{leaf_value:5.119874999999999},right_tree:{split_feature:Cl,split_value:0.3588181818181821,left_tree:{split_feature:NO3,split_value:1.1907373737373736,left_tree:{leaf_value:4.822402298850575},right_tree:{leaf_value:4.636166666666667}},right_tree:{leaf_value:5.029947368421053}}}},right_tree:{split_feature:NO3,split_value:2.802,left_tree:{leaf_value:4.390312499999999},right_tree:{leaf_value:4.0194375}}}
# {split_feature:Ca,split_value:0.038,left_tree:{split_feature:Ca,split_value:0.017,left_tree:{leaf_value:5.2441249999999995},right_tree:{leaf_value:4.969585714285715}},right_tree:{split_feature:K,split_value:0.019,left_tree:{split_feature:Ca,split_value:0.109,left_tree:{split_feature:K,split_value:0.01,left_tree:{leaf_value:4.686571428571431},right_tree:{split_feature:Ca,split_value:0.065,left_tree:{leaf_value:4.921097560975611},right_tree:{leaf_value:4.756038461538461}}},right_tree:{leaf_value:4.519510638297871}},right_tree:{split_feature:Ca,split_value:0.2,left_tree:{split_feature:K,split_value:0.027999999999999997,left_tree:{split_feature:Ca,split_value:0.127,left_tree:{leaf_value:4.82650980392157},right_tree:{leaf_value:5.19285}},right_tree:{split_feature:Ca,split_value:0.124,left_tree:{leaf_value:5.196242424242423},right_tree:{leaf_value:4.978035714285714}}},right_tree:{leaf_value:4.636857142857143}}}}
# {split_feature:SO4,split_value:0.9929999999999999,left_tree:{split_feature:SO4,split_value:0.373,left_tree:{leaf_value:5.31358695652174},right_tree:{split_feature:NO3,split_value:0.9933333333333336,left_tree:{split_feature:SO4,split_value:0.638,left_tree:{leaf_value:5.084183486238533},right_tree:{leaf_value:4.873999999999999}},right_tree:{leaf_value:5.2378275862068975}}},right_tree:{split_feature:SO4,split_value:1.6254545454545457,left_tree:{leaf_value:4.669825688073392},right_tree:{split_feature:SO4,split_value:2.654,left_tree:{split_feature:SO4,split_value:2.406,left_tree:{leaf_value:4.43851923076923},right_tree:{leaf_value:4.335636363636364}},right_tree:{leaf_value:4.197325581395348}}}}
# {split_feature:SO4,split_value:1.136,left_tree:{split_feature:SO4,split_value:0.5550808080808082,left_tree:{leaf_value:5.224398230088494},right_tree:{split_feature:Na,split_value:0.139,left_tree:{split_feature:SO4,split_value:0.794,left_tree:{leaf_value:4.947450980392157},right_tree:{leaf_value:4.7633409090909105}},right_tree:{leaf_value:5.098068965517241}}},right_tree:{split_feature:SO4,split_value:1.8519999999999999,left_tree:{split_feature:Na,split_value:0.221,left_tree:{leaf_value:4.581314285714287},right_tree:{leaf_value:4.885727272727272}},right_tree:{split_feature:SO4,split_value:3.063,left_tree:{split_feature:Na,split_value:0.02,left_tree:{leaf_value:4.475909090909091},right_tree:{leaf_value:4.372438596491229}},right_tree:{leaf_value:4.120571428571427}}}}
# feature importance: {'NO3': 12, 'NH4': 5, 'Cl': 2, 'Ca': 7, 'K': 3, 'SO4': 11, 'Na': 3}
# fold: 0, error train: 0.05578572777949711
# fold: 0, error val: 0.07090723272349571
# fold: 0, error test: 0.0553125116158659
# {split_feature:NO3,split_value:1.1370707070707071,left_tree:{split_feature:NH4,split_value:0.4607272727272731,left_tree:{split_feature:NO3,split_value:0.615060606060606,left_tree:{split_feature:NH4,split_value:0.25,left_tree:{split_feature:NO3,split_value:0.331,left_tree:{leaf_value:5.2817037037037045},right_tree:{leaf_value:5.04890277777778}},right_tree:{leaf_value:5.575333333333333}},right_tree:{split_feature:NH4,split_value:0.221,left_tree:{split_feature:NO3,split_value:0.763,left_tree:{leaf_value:4.779384615384615},right_tree:{leaf_value:4.594632653061225}},right_tree:{split_feature:NO3,split_value:0.82,left_tree:{leaf_value:5.1118571428571435},right_tree:{leaf_value:4.771686274509803}}}},right_tree:{leaf_value:5.646206896551724}},right_tree:{split_feature:NO3,split_value:1.839,left_tree:{split_feature:NH4,split_value:0.406,left_tree:{leaf_value:4.45831914893617},right_tree:{leaf_value:4.754214285714286}},right_tree:{leaf_value:4.246674418604651}}}
# {split_feature:NO3,split_value:1.4513838383838387,left_tree:{split_feature:NO3,split_value:0.6694242424242425,left_tree:{split_feature:NO3,split_value:0.609,left_tree:{split_feature:NO3,split_value:0.469,left_tree:{split_feature:Cl,split_value:0.16399999999999998,left_tree:{leaf_value:5.2041562500000005},right_tree:{leaf_value:5.058739130434782}},right_tree:{leaf_value:5.039400000000001}},right_tree:{leaf_value:5.242055555555556}},right_tree:{split_feature:NO3,split_value:1.3458484848484848,left_tree:{split_feature:NO3,split_value:1.1706161616161617,left_tree:{split_feature:Cl,split_value:0.06613131313131314,left_tree:{leaf_value:4.986407407407408},right_tree:{leaf_value:4.786595375722542}},right_tree:{leaf_value:4.573976190476191}},right_tree:{leaf_value:5.1933125}}},right_tree:{split_feature:NO3,split_value:2.269,left_tree:{leaf_value:4.425408163265305},right_tree:{leaf_value:4.140041666666666}}}
# {split_feature:Ca,split_value:0.016151515151515153,left_tree:{leaf_value:5.253714285714286},right_tree:{split_feature:Ca,split_value:0.14385858585858594,left_tree:{leaf_value:4.851313186813187},right_tree:{split_feature:K,split_value:0.024,left_tree:{leaf_value:4.474346153846155},right_tree:{leaf_value:4.766866666666668}}}}
# {split_feature:SO4,split_value:0.9804343434343435,left_tree:{split_feature:SO4,split_value:0.373,left_tree:{leaf_value:5.320222222222222},right_tree:{split_feature:NO3,split_value:0.9885252525252527,left_tree:{split_feature:SO4,split_value:0.638,left_tree:{leaf_value:5.115271739130436},right_tree:{leaf_value:4.890765957446807}},right_tree:{leaf_value:5.2378275862068975}}},right_tree:{split_feature:SO4,split_value:1.6409090909090907,left_tree:{leaf_value:4.649640350877193},right_tree:{split_feature:SO4,split_value:2.4730000000000003,left_tree:{split_feature:NO3,split_value:1.368,left_tree:{leaf_value:4.456450000000001},right_tree:{leaf_value:4.381600000000001}},right_tree:{leaf_value:4.1993269230769235}}}}
# {split_feature:SO4,split_value:0.963,left_tree:{split_feature:SO4,split_value:0.556939393939394,left_tree:{leaf_value:5.237954128440367},right_tree:{split_feature:Na,split_value:0.13699999999999998,left_tree:{split_feature:SO4,split_value:0.794,left_tree:{leaf_value:4.945854166666666},right_tree:{leaf_value:4.760416666666667}},right_tree:{leaf_value:5.198222222222222}}},right_tree:{split_feature:SO4,split_value:1.6365454545454543,left_tree:{split_feature:Na,split_value:0.221,left_tree:{split_feature:SO4,split_value:1.136,left_tree:{leaf_value:4.7826315789473695},right_tree:{leaf_value:4.607623376623377}},right_tree:{leaf_value:4.878349999999999}},right_tree:{split_feature:SO4,split_value:3.063,left_tree:{split_feature:SO4,split_value:2.324,left_tree:{leaf_value:4.451227272727273},right_tree:{leaf_value:4.364878787878787}},right_tree:{leaf_value:4.135464285714284}}}}
# feature importance: {'NO3': 15, 'NH4': 4, 'Cl': 2, 'Ca': 2, 'K': 1, 'SO4': 12, 'Na': 2}
# fold: 1, error train: 0.05682459514767834
# fold: 1, error val: 0.09460613443990024
# fold: 1, error test: 0.033469685325430876
# {split_feature:NO3,split_value:1.1429595959595962,left_tree:{split_feature:NH4,split_value:0.47072727272727294,left_tree:{split_feature:NO3,split_value:0.766,left_tree:{split_feature:NH4,split_value:0.266,left_tree:{split_feature:NO3,split_value:0.505,left_tree:{leaf_value:5.1173666666666655},right_tree:{leaf_value:4.874135802469136}},right_tree:{leaf_value:5.480999999999999}},right_tree:{split_feature:NH4,split_value:0.276,left_tree:{split_feature:NO3,split_value:0.8440000000000001,left_tree:{leaf_value:4.677233333333334},right_tree:{leaf_value:4.563519230769231}},right_tree:{leaf_value:4.8159}}},right_tree:{leaf_value:5.629607142857141}},right_tree:{split_feature:NO3,split_value:1.8499090909090912,left_tree:{split_feature:NH4,split_value:0.44799999999999995,left_tree:{split_feature:NO3,split_value:1.251,left_tree:{leaf_value:4.504428571428571},right_tree:{leaf_value:4.423619047619047}},right_tree:{leaf_value:4.707205128205128}},right_tree:{leaf_value:4.23986046511628}}}
# {split_feature:NO3,split_value:1.4534949494949498,left_tree:{split_feature:NO3,split_value:0.6696767676767678,left_tree:{split_feature:NO3,split_value:0.6,left_tree:{leaf_value:5.062533333333333},right_tree:{leaf_value:5.196789473684209}},right_tree:{split_feature:NO3,split_value:1.3444848484848486,left_tree:{split_feature:NO3,split_value:1.1425151515151515,left_tree:{split_feature:Cl,split_value:0.06372727272727273,left_tree:{leaf_value:5.0015},right_tree:{leaf_value:4.7475689655172415}},right_tree:{leaf_value:4.505285714285715}},right_tree:{leaf_value:5.072909090909092}}},right_tree:{split_feature:NO3,split_value:2.269,left_tree:{leaf_value:4.3929607843137255},right_tree:{leaf_value:4.127461538461538}}}
# {split_feature:Ca,split_value:0.036000000000000004,left_tree:{split_feature:Ca,split_value:0.017,left_tree:{leaf_value:5.241666666666666},right_tree:{leaf_value:4.903132352941178}},right_tree:{split_feature:K,split_value:0.018000000000000002,left_tree:{split_feature:Ca,split_value:0.109,left_tree:{split_feature:K,split_value:0.015,left_tree:{leaf_value:4.707735714285714},right_tree:{leaf_value:4.876666666666667}},right_tree:{leaf_value:4.518863636363635}},right_tree:{split_feature:K,split_value:0.065,left_tree:{leaf_value:4.907118881118883},right_tree:{leaf_value:4.550750000000001}}}}
# {split_feature:SO4,split_value:1.0897777777777777,left_tree:{split_feature:SO4,split_value:0.5563939393939394,left_tree:{split_feature:NO3,split_value:0.8440000000000001,left_tree:{split_feature:SO4,split_value:0.373,left_tree:{leaf_value:5.339184210526317},right_tree:{leaf_value:5.0891590909090905}},right_tree:{leaf_value:5.568727272727273}},right_tree:{split_feature:SO4,split_value:0.963,left_tree:{leaf_value:5.021690476190477},right_tree:{leaf_value:4.808521739130434}}},right_tree:{split_feature:SO4,split_value:1.8203131313131313,left_tree:{leaf_value:4.605694656488551},right_tree:{split_feature:SO4,split_value:3.2260000000000004,left_tree:{split_feature:SO4,split_value:2.319,left_tree:{leaf_value:4.425425531914894},right_tree:{leaf_value:4.300369565217392}},right_tree:{leaf_value:4.10272}}}}
# {split_feature:SO4,split_value:1.136,left_tree:{split_feature:SO4,split_value:0.5579999999999999,left_tree:{leaf_value:5.249540816326531},right_tree:{split_feature:Na,split_value:0.13699999999999998,left_tree:{split_feature:SO4,split_value:0.794,left_tree:{leaf_value:4.9501351351351355},right_tree:{leaf_value:4.76379069767442}},right_tree:{leaf_value:5.04037142857143}}},right_tree:{split_feature:SO4,split_value:1.8490404040404043,left_tree:{split_feature:Na,split_value:0.221,left_tree:{leaf_value:4.567400000000001},right_tree:{leaf_value:4.910818181818182}},right_tree:{split_feature:SO4,split_value:3.063,left_tree:{split_feature:SO4,split_value:2.464,left_tree:{leaf_value:4.419563636363636},right_tree:{leaf_value:4.337777777777777}},right_tree:{leaf_value:4.135464285714284}}}}
# feature importance: {'NO3': 13, 'NH4': 4, 'Cl': 1, 'Ca': 3, 'K': 3, 'SO4': 13, 'Na': 2}
# fold: 2, error train: 0.05754876159182505
# fold: 2, error val: 0.10298690139471944
# fold: 2, error test: 0.01884621776854619
# {split_feature:NO3,split_value:1.1432121212121213,left_tree:{split_feature:NH4,split_value:0.4665454545454547,left_tree:{split_feature:NO3,split_value:0.766,left_tree:{split_feature:NH4,split_value:0.266,left_tree:{split_feature:NO3,split_value:0.331,left_tree:{leaf_value:5.315142857142858},right_tree:{leaf_value:4.955671641791046}},right_tree:{leaf_value:5.449090909090907}},right_tree:{split_feature:NH4,split_value:0.276,left_tree:{split_feature:NO3,split_value:0.823,left_tree:{leaf_value:4.712458333333333},right_tree:{leaf_value:4.552892857142857}},right_tree:{leaf_value:4.8302941176470595}}},right_tree:{leaf_value:5.635965517241379}},right_tree:{split_feature:NO3,split_value:1.979,left_tree:{split_feature:NH4,split_value:0.44799999999999995,left_tree:{split_feature:NO3,split_value:1.5490000000000002,left_tree:{leaf_value:4.472382978723405},right_tree:{leaf_value:4.372111111111113}},right_tree:{leaf_value:4.693444444444444}},right_tree:{leaf_value:4.209384615384615}}}
# {split_feature:NO3,split_value:1.453,left_tree:{split_feature:NO3,split_value:0.669,left_tree:{leaf_value:5.060072727272729},right_tree:{split_feature:NO3,split_value:1.345,left_tree:{split_feature:NO3,split_value:1.147808080808081,left_tree:{split_feature:Cl,split_value:0.063,left_tree:{leaf_value:4.960478260869565},right_tree:{leaf_value:4.752906593406593}},right_tree:{leaf_value:4.545692307692309}},right_tree:{leaf_value:5.129315789473685}}},right_tree:{split_feature:NO3,split_value:2.269,left_tree:{leaf_value:4.394282608695652},right_tree:{leaf_value:4.1142352941176465}}}
# {leaf_value:4.788383073496656}
# {split_feature:SO4,split_value:1.0959999999999999,left_tree:{split_feature:SO4,split_value:0.5567777777777778,left_tree:{split_feature:NO3,split_value:0.7929999999999999,left_tree:{split_feature:SO4,split_value:0.425,left_tree:{leaf_value:5.246338709677416},right_tree:{leaf_value:5.036608695652174}},right_tree:{leaf_value:5.574583333333333}},right_tree:{split_feature:SO4,split_value:0.977,left_tree:{split_feature:NO3,split_value:1.0170000000000001,left_tree:{split_feature:SO4,split_value:0.7859999999999999,left_tree:{leaf_value:4.998677966101695},right_tree:{leaf_value:4.853479999999999}},right_tree:{leaf_value:5.23775}},right_tree:{leaf_value:4.78681818181818}}},right_tree:{split_feature:SO4,split_value:1.8235454545454546,left_tree:{leaf_value:4.611152000000001},right_tree:{split_feature:SO4,split_value:2.654,left_tree:{split_feature:SO4,split_value:2.319,left_tree:{leaf_value:4.43054347826087},right_tree:{leaf_value:4.3311}},right_tree:{leaf_value:4.176333333333334}}}}
# {split_feature:SO4,split_value:1.136,left_tree:{split_feature:SO4,split_value:0.558090909090909,left_tree:{split_feature:SO4,split_value:0.43799999999999994,left_tree:{leaf_value:5.31949019607843},right_tree:{leaf_value:5.113999999999999}},right_tree:{split_feature:Na,split_value:0.13699999999999998,left_tree:{split_feature:SO4,split_value:0.794,left_tree:{leaf_value:4.921236363636364},right_tree:{leaf_value:4.796640000000002}},right_tree:{leaf_value:5.0382500000000014}}},right_tree:{split_feature:SO4,split_value:1.8454545454545455,left_tree:{leaf_value:4.598245901639344},right_tree:{split_feature:SO4,split_value:3.063,left_tree:{split_feature:SO4,split_value:2.457,left_tree:{leaf_value:4.427},right_tree:{leaf_value:4.3347500000000005}},right_tree:{leaf_value:4.138115384615383}}}}
# feature importance: {'NO3': 13, 'NH4': 4, 'Cl': 1, 'SO4': 15, 'Na': 1}
# fold: 3, error train: 0.05620404114947956
# fold: 3, error val: 0.10415108221867812
# fold: 3, error test: 0.0406099976342823
# {split_feature:NO3,split_value:1.444,left_tree:{split_feature:NH4,split_value:0.48854545454545456,left_tree:{split_feature:NO3,split_value:0.7759999999999999,left_tree:{split_feature:NO3,split_value:0.32842424242424245,left_tree:{leaf_value:5.346999999999999},right_tree:{leaf_value:5.0101696969696965}},right_tree:{split_feature:NO3,split_value:0.959909090909091,left_tree:{split_feature:NH4,split_value:0.276,left_tree:{leaf_value:4.636283018867926},right_tree:{leaf_value:4.984807692307693}},right_tree:{split_feature:NH4,split_value:0.335,left_tree:{leaf_value:4.526109375},right_tree:{leaf_value:4.6578928571428575}}}},right_tree:{leaf_value:5.426277777777776}},right_tree:{split_feature:NO3,split_value:1.912,left_tree:{leaf_value:4.491060606060606},right_tree:{leaf_value:4.199160000000001}}}
# {split_feature:NO3,split_value:0.924,left_tree:{split_feature:NO3,split_value:0.6166363636363636,left_tree:{leaf_value:5.147368421052633},right_tree:{split_feature:NO3,split_value:0.884,left_tree:{split_feature:Cl,split_value:0.124,left_tree:{split_feature:NO3,split_value:0.7609999999999999,left_tree:{leaf_value:5.069875000000001},right_tree:{leaf_value:4.857148148148149}},right_tree:{split_feature:Cl,split_value:0.345,left_tree:{leaf_value:4.7153333333333345},right_tree:{leaf_value:5.026400000000001}}},right_tree:{leaf_value:5.251769230769231}}},right_tree:{split_feature:NO3,split_value:1.9620000000000002,left_tree:{split_feature:NO3,split_value:1.4536363636363638,left_tree:{split_feature:NO3,split_value:1.3419999999999999,left_tree:{split_feature:NO3,split_value:1.143,left_tree:{leaf_value:4.726315068493152},right_tree:{leaf_value:4.5402666666666684}},right_tree:{leaf_value:5.103590909090911}},right_tree:{leaf_value:4.517193548387097}},right_tree:{leaf_value:4.221178571428571}}}
# {split_feature:Ca,split_value:0.038,left_tree:{leaf_value:5.012034482758623},right_tree:{leaf_value:4.815936464088395}}
# {split_feature:SO4,split_value:1.1157878787878788,left_tree:{split_feature:SO4,split_value:0.5558282828282829,left_tree:{split_feature:NO3,split_value:0.878,left_tree:{split_feature:SO4,split_value:0.34600000000000003,left_tree:{leaf_value:5.264627450980391},right_tree:{split_feature:NO3,split_value:0.737,left_tree:{leaf_value:5.140560975609756},right_tree:{leaf_value:4.987692307692307}}},right_tree:{leaf_value:5.4585333333333335}},right_tree:{split_feature:NO3,split_value:1.347,left_tree:{split_feature:SO4,split_value:0.68,left_tree:{leaf_value:5.0469230769230755},right_tree:{split_feature:NO3,split_value:0.9840000000000001,left_tree:{leaf_value:4.865937499999999},right_tree:{leaf_value:5.033608695652172}}},right_tree:{leaf_value:5.28725}}},right_tree:{split_feature:SO4,split_value:1.845,left_tree:{split_feature:SO4,split_value:1.276,left_tree:{leaf_value:4.733967741935484},right_tree:{split_feature:SO4,split_value:1.429,left_tree:{leaf_value:4.586971428571429},right_tree:{leaf_value:4.51835294117647}}},right_tree:{split_feature:SO4,split_value:3.14,left_tree:{split_feature:SO4,split_value:2.324,left_tree:{leaf_value:4.433642857142856},right_tree:{leaf_value:4.304290322580645}},right_tree:{leaf_value:4.1024}}}}
# {split_feature:SO4,split_value:1.2061616161616164,left_tree:{split_feature:SO4,split_value:0.604,left_tree:{leaf_value:5.172929687500001},right_tree:{split_feature:Na,split_value:0.139,left_tree:{split_feature:SO4,split_value:1.055,left_tree:{leaf_value:4.870247058823528},right_tree:{leaf_value:4.6912}},right_tree:{leaf_value:4.980477272727272}}},right_tree:{split_feature:SO4,split_value:2.319,left_tree:{split_feature:SO4,split_value:1.4269999999999998,left_tree:{leaf_value:4.6719189189189185},right_tree:{split_feature:Na,split_value:0.05,left_tree:{leaf_value:4.576200000000001},right_tree:{leaf_value:4.46278260869565}}},right_tree:{split_feature:SO4,split_value:3.367,left_tree:{leaf_value:4.328500000000001},right_tree:{leaf_value:4.059636363636364}}}}
# feature importance: {'NO3': 17, 'NH4': 3, 'Cl': 2, 'Ca': 1, 'SO4': 15, 'Na': 2}
# fold: 4, error train: 0.06314506902162095
# fold: 4, error val: 0.11089947830507448
# fold: 4, error test: 0.03298689360027476
# {split_feature:NO3,split_value:1.072,left_tree:{split_feature:NH4,split_value:0.45799999999999996,left_tree:{split_feature:NO3,split_value:0.7655050505050506,left_tree:{split_feature:NH4,split_value:0.252,left_tree:{split_feature:NO3,split_value:0.331,left_tree:{leaf_value:5.308571428571428},right_tree:{leaf_value:4.966246376811595}},right_tree:{leaf_value:5.368035714285713}},right_tree:{split_feature:NH4,split_value:0.276,left_tree:{leaf_value:4.616731707317074},right_tree:{leaf_value:4.8026}}},right_tree:{leaf_value:5.701479999999999}},right_tree:{split_feature:NO3,split_value:1.962,left_tree:{split_feature:NH4,split_value:0.521,left_tree:{split_feature:NH4,split_value:0.406,left_tree:{split_feature:NO3,split_value:1.2429999999999999,left_tree:{leaf_value:4.5089999999999995},right_tree:{leaf_value:4.398475}},right_tree:{leaf_value:4.584047619047619}},right_tree:{leaf_value:4.9245625}},right_tree:{leaf_value:4.182375}}}
# {split_feature:NO3,split_value:1.4538484848484852,left_tree:{split_feature:NO3,split_value:0.67,left_tree:{split_feature:NO3,split_value:0.33799999999999997,left_tree:{leaf_value:5.2203333333333335},right_tree:{split_feature:NO3,split_value:0.593,left_tree:{split_feature:Cl,split_value:0.214,left_tree:{leaf_value:5.071166666666668},right_tree:{leaf_value:4.9537272727272725}},right_tree:{leaf_value:5.13186111111111}}},right_tree:{split_feature:NO3,split_value:1.3453434343434345,left_tree:{split_feature:NO3,split_value:1.0720303030303031,left_tree:{split_feature:Cl,split_value:0.066,left_tree:{leaf_value:4.9585333333333335},right_tree:{leaf_value:4.757856}},right_tree:{leaf_value:4.588208955223882}},right_tree:{leaf_value:5.142176470588236}}},right_tree:{split_feature:NO3,split_value:1.912,left_tree:{leaf_value:4.474593750000001},right_tree:{leaf_value:4.193499999999999}}}
# {split_feature:K,split_value:0.065,left_tree:{leaf_value:4.831494004796161},right_tree:{leaf_value:4.562062500000001}}
# {split_feature:SO4,split_value:0.9630000000000001,left_tree:{split_feature:SO4,split_value:0.556878787878788,left_tree:{split_feature:NO3,split_value:0.8240000000000001,left_tree:{split_feature:SO4,split_value:0.373,left_tree:{leaf_value:5.260203124999998},right_tree:{split_feature:NO3,split_value:0.561,left_tree:{leaf_value:5.045809523809524},right_tree:{leaf_value:5.153766666666667}}},right_tree:{leaf_value:5.514666666666667}},right_tree:{leaf_value:5.007712643678161}},right_tree:{split_feature:SO4,split_value:1.6246363636363639,left_tree:{leaf_value:4.643621848739497},right_tree:{split_feature:SO4,split_value:3.14,left_tree:{split_feature:SO4,split_value:2.167,left_tree:{leaf_value:4.4285},right_tree:{leaf_value:4.332244897959184}},right_tree:{leaf_value:4.100285714285714}}}}
# {split_feature:SO4,split_value:1.203,left_tree:{split_feature:SO4,split_value:0.5579999999999999,left_tree:{split_feature:SO4,split_value:0.402,left_tree:{leaf_value:5.24731746031746},right_tree:{split_feature:Na,split_value:0.064,left_tree:{leaf_value:5.233863636363638},right_tree:{leaf_value:5.030896551724138}}},right_tree:{split_feature:SO4,split_value:0.963,left_tree:{split_feature:Na,split_value:0.13699999999999998,left_tree:{leaf_value:4.899376811594202},right_tree:{leaf_value:5.182842105263158}},right_tree:{leaf_value:4.748452830188682}}},right_tree:{split_feature:SO4,split_value:2.654,left_tree:{split_feature:SO4,split_value:1.393,left_tree:{leaf_value:4.647617647058824},right_tree:{split_feature:SO4,split_value:1.845,left_tree:{split_feature:Na,split_value:0.037000000000000005,left_tree:{leaf_value:4.547266666666667},right_tree:{leaf_value:4.489124999999999}},right_tree:{split_feature:Na,split_value:0.028999999999999998,left_tree:{leaf_value:4.450181818181818},right_tree:{leaf_value:4.385682926829269}}}},right_tree:{split_feature:SO4,split_value:3.2260000000000004,left_tree:{leaf_value:4.272148148148149},right_tree:{leaf_value:4.078730769230768}}}}
# feature importance: {'NO3': 14, 'NH4': 5, 'Cl': 2, 'K': 1, 'SO4': 14, 'Na': 4}
# fold: 5, error train: 0.05448935492689701
# fold: 5, error val: 0.10774449954291596
# fold: 5, error test: 0.04188966778308457
# {split_feature:NO3,split_value:0.752,left_tree:{split_feature:NH4,split_value:0.266,left_tree:{split_feature:NO3,split_value:0.335,left_tree:{leaf_value:5.269285714285714},right_tree:{split_feature:NO3,split_value:0.5,left_tree:{split_feature:NO3,split_value:0.384,left_tree:{leaf_value:4.9470399999999985},right_tree:{leaf_value:5.083096774193549}},right_tree:{split_feature:NH4,split_value:0.139,left_tree:{leaf_value:4.78590625},right_tree:{leaf_value:4.9988222222222225}}}},right_tree:{leaf_value:5.606466666666666}},right_tree:{split_feature:NO3,split_value:1.1159999999999999,left_tree:{split_feature:NH4,split_value:0.46399999999999997,left_tree:{split_feature:NH4,split_value:0.3,left_tree:{split_feature:NO3,split_value:0.8690000000000001,left_tree:{leaf_value:4.678295454545455},right_tree:{leaf_value:4.575326923076923}},right_tree:{leaf_value:4.769235294117648}},right_tree:{leaf_value:5.561076923076923}},right_tree:{split_feature:NO3,split_value:1.9269999999999998,left_tree:{split_feature:NH4,split_value:0.562,left_tree:{split_feature:NH4,split_value:0.387,left_tree:{leaf_value:4.432666666666666},right_tree:{leaf_value:4.552185185185184}},right_tree:{leaf_value:4.7186}},right_tree:{leaf_value:4.182375}}}}
# {split_feature:NO3,split_value:0.669,left_tree:{leaf_value:5.083046511627906},right_tree:{split_feature:NO3,split_value:1.553555555555556,left_tree:{split_feature:Cl,split_value:0.35655555555555585,left_tree:{split_feature:NO3,split_value:1.115,left_tree:{split_feature:Cl,split_value:0.225,left_tree:{leaf_value:4.7383412698412695},right_tree:{leaf_value:4.607428571428571}},right_tree:{split_feature:Cl,split_value:0.192,left_tree:{leaf_value:4.488454545454547},right_tree:{leaf_value:4.683}}},right_tree:{leaf_value:4.900428571428572}},right_tree:{split_feature:NO3,split_value:2.7260000000000004,left_tree:{leaf_value:4.37748275862069},right_tree:{leaf_value:4.092}}}}
# {split_feature:Ca,split_value:0.07321212121212121,left_tree:{split_feature:Ca,split_value:0.017,left_tree:{leaf_value:5.2459999999999996},right_tree:{split_feature:K,split_value:0.043,left_tree:{split_feature:K,split_value:0.028999999999999998,left_tree:{split_feature:Ca,split_value:0.038,left_tree:{leaf_value:4.899346666666668},right_tree:{leaf_value:4.754480769230767}},right_tree:{leaf_value:5.2185}},right_tree:{leaf_value:4.582866666666667}}},right_tree:{split_feature:K,split_value:0.032,left_tree:{leaf_value:4.595366279069765},right_tree:{split_feature:K,split_value:0.063,left_tree:{leaf_value:4.882523809523811},right_tree:{leaf_value:4.543705882352942}}}}
# {split_feature:SO4,split_value:1.150949494949495,left_tree:{split_feature:SO4,split_value:0.7389494949494951,left_tree:{leaf_value:5.143377622377622},right_tree:{split_feature:NO3,split_value:0.935,left_tree:{leaf_value:4.762063829787234},right_tree:{leaf_value:4.8966875}}},right_tree:{split_feature:SO4,split_value:1.7951515151515152,left_tree:{leaf_value:4.595254716981131},right_tree:{split_feature:SO4,split_value:3.5069999999999997,left_tree:{split_feature:SO4,split_value:2.324,left_tree:{leaf_value:4.416596153846156},right_tree:{split_feature:SO4,split_value:2.654,left_tree:{leaf_value:4.3488928571428564},right_tree:{leaf_value:4.275846153846153}}},right_tree:{leaf_value:4.0527999999999995}}}}
# {split_feature:SO4,split_value:1.136,left_tree:{split_feature:SO4,split_value:0.5520909090909091,left_tree:{split_feature:SO4,split_value:0.402,left_tree:{leaf_value:5.244660714285713},right_tree:{leaf_value:5.059171428571428}},right_tree:{split_feature:Na,split_value:0.13699999999999998,left_tree:{split_feature:SO4,split_value:1.022,left_tree:{split_feature:Na,split_value:0.061,left_tree:{leaf_value:4.8110263157894755},right_tree:{leaf_value:4.934575757575757}},right_tree:{leaf_value:4.679681818181819}},right_tree:{leaf_value:4.985694444444444}}},right_tree:{split_feature:SO4,split_value:2.654,left_tree:{split_feature:SO4,split_value:1.7542727272727272,left_tree:{leaf_value:4.592056603773585},right_tree:{leaf_value:4.41423188405797}},right_tree:{split_feature:SO4,split_value:3.2260000000000004,left_tree:{leaf_value:4.272148148148149},right_tree:{leaf_value:4.081259259259259}}}}
# feature importance: {'NO3': 12, 'NH4': 6, 'Cl': 3, 'Ca': 3, 'K': 4, 'SO4': 13, 'Na': 2}
# fold: 6, error train: 0.041263192806984005
# fold: 6, error val: 0.11767389941778772
# fold: 6, error test: 0.22182255207645596
# {split_feature:NO3,split_value:0.9254545454545453,left_tree:{split_feature:NH4,split_value:0.3600606060606062,left_tree:{split_feature:NO3,split_value:0.737,left_tree:{split_feature:NO3,split_value:0.331,left_tree:{leaf_value:5.368409090909091},right_tree:{split_feature:NH4,split_value:0.187,left_tree:{leaf_value:4.9366489361702115},right_tree:{leaf_value:5.106295454545455}}},right_tree:{split_feature:NH4,split_value:0.267,left_tree:{leaf_value:4.666509803921569},right_tree:{leaf_value:4.882894736842107}}},right_tree:{leaf_value:5.526266666666667}},right_tree:{leaf_value:4.588602941176471}}
# {split_feature:NO3,split_value:0.9414545454545453,left_tree:{split_feature:NO3,split_value:0.6268181818181818,left_tree:{leaf_value:5.080729729729731},right_tree:{leaf_value:4.829365671641793}},right_tree:{split_feature:NO3,split_value:1.9121818181818182,left_tree:{split_feature:Cl,split_value:0.192,left_tree:{split_feature:NO3,split_value:1.453,left_tree:{split_feature:Cl,split_value:0.142,left_tree:{leaf_value:4.6895555555555575},right_tree:{leaf_value:4.499879999999999}},right_tree:{leaf_value:4.3705}},right_tree:{leaf_value:4.753150943396227}},right_tree:{leaf_value:4.213324324324324}}}
# {split_feature:Ca,split_value:0.094,left_tree:{split_feature:K,split_value:0.065,left_tree:{split_feature:K,split_value:0.027000000000000003,left_tree:{leaf_value:4.858735177865611},right_tree:{leaf_value:5.23008695652174}},right_tree:{leaf_value:4.5348749999999995}},right_tree:{split_feature:K,split_value:0.018000000000000002,left_tree:{leaf_value:4.533736842105263},right_tree:{leaf_value:4.796029999999999}}}
# {split_feature:SO4,split_value:1.1496565656565656,left_tree:{split_feature:SO4,split_value:0.638,left_tree:{split_feature:NO3,split_value:0.231,left_tree:{leaf_value:5.4209999999999985},right_tree:{leaf_value:5.129028776978417}},right_tree:{leaf_value:4.900196078431371}},right_tree:{split_feature:SO4,split_value:1.7959090909090907,left_tree:{leaf_value:4.621273684210525},right_tree:{split_feature:SO4,split_value:3.404,left_tree:{split_feature:SO4,split_value:2.324,left_tree:{leaf_value:4.418636363636365},right_tree:{leaf_value:4.326199999999999}},right_tree:{leaf_value:4.085999999999999}}}}
# {split_feature:SO4,split_value:1.136,left_tree:{split_feature:SO4,split_value:0.4620000000000001,left_tree:{leaf_value:5.184261904761905},right_tree:{split_feature:SO4,split_value:0.948,left_tree:{split_feature:Na,split_value:0.11800000000000001,left_tree:{leaf_value:4.9255287356321835},right_tree:{leaf_value:5.0315}},right_tree:{leaf_value:4.796666666666667}}},right_tree:{split_feature:SO4,split_value:2.165,left_tree:{split_feature:SO4,split_value:1.393,left_tree:{leaf_value:4.669795918367346},right_tree:{split_feature:SO4,split_value:1.84,left_tree:{split_feature:Na,split_value:0.049,left_tree:{leaf_value:4.5907368421052634},right_tree:{leaf_value:4.50381081081081}},right_tree:{leaf_value:4.450590909090909}}},right_tree:{split_feature:SO4,split_value:3.2260000000000004,left_tree:{leaf_value:4.328080000000002},right_tree:{leaf_value:4.095454545454546}}}}
# feature importance: {'NO3': 8, 'NH4': 3, 'Cl': 2, 'Ca': 1, 'K': 3, 'SO4': 12, 'Na': 2}
# fold: 7, error train: 0.05762850146855721
# fold: 7, error val: 0.12439483886198532
# fold: 7, error test: 0.1487102527115901
# {split_feature:NO3,split_value:0.7664343434343435,left_tree:{leaf_value:5.0362380952380965},right_tree:{split_feature:NO3,split_value:1.453,left_tree:{split_feature:NH4,split_value:0.48945454545454586,left_tree:{split_feature:NH4,split_value:0.3056262626262627,left_tree:{split_feature:NO3,split_value:1.041,left_tree:{leaf_value:4.60844927536232},right_tree:{leaf_value:4.474418604651164}},right_tree:{leaf_value:4.7013428571428575}},right_tree:{leaf_value:5.3147199999999994}},right_tree:{split_feature:NO3,split_value:1.962,left_tree:{leaf_value:4.485652173913044},right_tree:{leaf_value:4.1964999999999995}}}}
# {split_feature:NO3,split_value:1.0812020202020205,left_tree:{split_feature:NO3,split_value:0.6528181818181819,left_tree:{split_feature:Cl,split_value:0.092,left_tree:{leaf_value:5.2039591836734695},right_tree:{leaf_value:4.99809090909091}},right_tree:{split_feature:Cl,split_value:0.168,left_tree:{leaf_value:4.878019801980198},right_tree:{leaf_value:4.663759999999999}}},right_tree:{split_feature:NO3,split_value:1.912,left_tree:{split_feature:Cl,split_value:0.192,left_tree:{split_feature:NO3,split_value:1.453,left_tree:{split_feature:NO3,split_value:1.334,left_tree:{leaf_value:4.56351851851852},right_tree:{leaf_value:4.789692307692308}},right_tree:{leaf_value:4.3524}},right_tree:{leaf_value:4.7418571428571425}},right_tree:{leaf_value:4.227894736842106}}}
# {split_feature:K,split_value:0.065,left_tree:{split_feature:Ca,split_value:0.094,left_tree:{split_feature:K,split_value:0.026000000000000002,left_tree:{leaf_value:4.849395437262356},right_tree:{leaf_value:5.343714285714286}},right_tree:{split_feature:K,split_value:0.018000000000000002,left_tree:{leaf_value:4.588666666666666},right_tree:{split_feature:K,split_value:0.044000000000000004,left_tree:{leaf_value:4.7738591549295775},right_tree:{leaf_value:5.104}}}},right_tree:{leaf_value:4.455260869565215}}
# {split_feature:SO4,split_value:1.252,left_tree:{split_feature:SO4,split_value:0.604,left_tree:{leaf_value:5.225916129032259},right_tree:{leaf_value:4.901221153846153}},right_tree:{split_feature:SO4,split_value:2.264727272727273,left_tree:{split_feature:SO4,split_value:1.795,left_tree:{leaf_value:4.5539444444444435},right_tree:{leaf_value:4.4239487179487185}},right_tree:{split_feature:SO4,split_value:3.5069999999999997,left_tree:{split_feature:SO4,split_value:2.654,left_tree:{leaf_value:4.352810810810811},right_tree:{leaf_value:4.269521739130434}},right_tree:{leaf_value:4.054}}}}
# {split_feature:SO4,split_value:0.964545454545455,left_tree:{split_feature:SO4,split_value:0.4607474747474748,left_tree:{leaf_value:5.252587628865982},right_tree:{split_feature:SO4,split_value:0.732,left_tree:{leaf_value:5.074666666666667},right_tree:{leaf_value:4.902789473684211}}},right_tree:{split_feature:SO4,split_value:1.879151515151515,left_tree:{split_feature:SO4,split_value:1.214,left_tree:{split_feature:Na,split_value:0.139,left_tree:{leaf_value:4.687488372093023},right_tree:{leaf_value:4.966866666666665}},right_tree:{leaf_value:4.540788888888888}},right_tree:{split_feature:SO4,split_value:3.2260000000000004,left_tree:{split_feature:SO4,split_value:2.64,left_tree:{leaf_value:4.3910454545454565},right_tree:{leaf_value:4.2811200000000005}},right_tree:{leaf_value:4.085999999999999}}}}
# feature importance: {'NO3': 9, 'NH4': 2, 'Cl': 3, 'K': 4, 'Ca': 1, 'SO4': 13, 'Na': 1}
# fold: 8, error train: 0.05931472248501687
# fold: 8, error val: 0.12055399564943602
# fold: 8, error test: 0.06492286921923413
# {split_feature:NO3,split_value:0.7664343434343435,left_tree:{leaf_value:5.0362380952380965},right_tree:{split_feature:NO3,split_value:1.453,left_tree:{split_feature:NH4,split_value:0.48945454545454586,left_tree:{split_feature:NH4,split_value:0.3056262626262627,left_tree:{split_feature:NO3,split_value:1.041,left_tree:{leaf_value:4.60844927536232},right_tree:{leaf_value:4.474418604651164}},right_tree:{leaf_value:4.7013428571428575}},right_tree:{leaf_value:5.3147199999999994}},right_tree:{split_feature:NO3,split_value:1.962,left_tree:{leaf_value:4.485652173913044},right_tree:{leaf_value:4.1964999999999995}}}}
# {split_feature:NO3,split_value:1.0812020202020205,left_tree:{split_feature:NO3,split_value:0.6595454545454547,left_tree:{split_feature:Cl,split_value:0.092,left_tree:{leaf_value:5.2049},right_tree:{leaf_value:4.996565789473684}},right_tree:{split_feature:Cl,split_value:0.168,left_tree:{leaf_value:4.875069306930694},right_tree:{leaf_value:4.663759999999999}}},right_tree:{split_feature:NO3,split_value:1.912,left_tree:{split_feature:Cl,split_value:0.192,left_tree:{split_feature:NO3,split_value:1.453,left_tree:{split_feature:NO3,split_value:1.334,left_tree:{leaf_value:4.56351851851852},right_tree:{leaf_value:4.789692307692308}},right_tree:{leaf_value:4.3524}},right_tree:{leaf_value:4.7418571428571425}},right_tree:{leaf_value:4.227894736842106}}}
# {split_feature:K,split_value:0.065,left_tree:{split_feature:Ca,split_value:0.094,left_tree:{split_feature:K,split_value:0.026000000000000002,left_tree:{leaf_value:4.848385496183205},right_tree:{leaf_value:5.343714285714286}},right_tree:{split_feature:K,split_value:0.018000000000000002,left_tree:{leaf_value:4.588666666666666},right_tree:{split_feature:K,split_value:0.044000000000000004,left_tree:{leaf_value:4.7738591549295775},right_tree:{leaf_value:5.0914166666666665}}}},right_tree:{leaf_value:4.455260869565215}}
# {split_feature:SO4,split_value:1.2570000000000001,left_tree:{split_feature:SO4,split_value:0.604,left_tree:{leaf_value:5.227379084967321},right_tree:{leaf_value:4.898896226415094}},right_tree:{split_feature:SO4,split_value:2.264727272727273,left_tree:{split_feature:SO4,split_value:1.795,left_tree:{leaf_value:4.558805555555555},right_tree:{leaf_value:4.4239487179487185}},right_tree:{split_feature:SO4,split_value:3.5069999999999997,left_tree:{split_feature:SO4,split_value:2.654,left_tree:{leaf_value:4.352810810810811},right_tree:{leaf_value:4.269521739130434}},right_tree:{leaf_value:4.054}}}}
# {split_feature:SO4,split_value:0.9803232323232324,left_tree:{split_feature:SO4,split_value:0.4612929292929293,left_tree:{leaf_value:5.252587628865982},right_tree:{split_feature:SO4,split_value:0.732,left_tree:{leaf_value:5.074088235294118},right_tree:{leaf_value:4.886772727272729}}},right_tree:{split_feature:SO4,split_value:1.8760404040404044,left_tree:{split_feature:SO4,split_value:1.214,left_tree:{split_feature:Na,split_value:0.139,left_tree:{leaf_value:4.673589743589744},right_tree:{leaf_value:5.006384615384615}},right_tree:{leaf_value:4.5453186813186806}},right_tree:{split_feature:SO4,split_value:3.2260000000000004,left_tree:{split_feature:SO4,split_value:2.64,left_tree:{leaf_value:4.3910454545454565},right_tree:{leaf_value:4.2811200000000005}},right_tree:{leaf_value:4.085999999999999}}}}
# feature importance: {'NO3': 9, 'NH4': 2, 'Cl': 3, 'K': 4, 'Ca': 1, 'SO4': 13, 'Na': 1}
# fold: 9, error train: 0.05930051491293221
# fold: 9, error val: 0.0650622440582909
# fold: 9, error test: 0.1204917136321003
